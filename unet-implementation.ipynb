# %% [markdown]
# ### Import required library and packages

# %%
import os
import numpy as np
import cv2
from glob import glob
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, CSVLogger, EarlyStopping
import matplotlib.pyplot as plt
from tqdm import tqdm
import urllib
import IPython
# Out:
# 2023-03-27 16:45:08.242002: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-27 16:45:08.710449: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-03-27 16:45:23.781208: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/rparchiev/.local/lib/python3.10/site-packages/cv2/../../lib64::/usr/local/lib:/usr/local/cuda/lib64:/home/rparchiev/miniconda3/lib/
# 2023-03-27 16:45:23.787719: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/rparchiev/.local/lib/python3.10/site-packages/cv2/../../lib64::/usr/local/lib:/usr/local/cuda/lib64:/home/rparchiev/miniconda3/lib/
# 2023-03-27 16:45:23.787747: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Build UNet Architecture

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

# %%
def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

# %%
def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding='same')(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

# %%
def build_unet(input_shape):
    inputs = Input(input_shape)

    """ Encoder """
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    """ Output """
    outputs = Conv2D(1, (1, 1), padding="same", activation="sigmoid")(d4)
    return Model(inputs, outputs, name="U-Net")

# %%
def load_data(dataset_path):
    images = sorted(glob(os.path.join(dataset_path, "images/*")))
    masks = sorted(glob(os.path.join(dataset_path, "masks/*")))
    train_x, test_x = train_test_split(images, test_size=0.2, random_state=42)
    train_y, test_y = train_test_split(masks, test_size=0.2, random_state=42)
    return (train_x, train_y), (test_x, test_y)

# %%
def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (256, 256))
    x = x/255.0
    x = x.astype(np.float32)
    # (256, 256, 3)
    return x

# %%
def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (256, 256))
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)
    return x

# %%
def preprocess(image_path, mask_path):
    def f(image_path, mask_path):
        image_path = image_path.decode()
        mask_path = mask_path.decode()
        x = read_image(image_path)
        y = read_mask(mask_path)
        return x, y
    image, mask = tf.numpy_function(f, [image_path, mask_path], [tf.float32, tf.float32])
    image.set_shape([256, 256, 3])
    mask.set_shape([256, 256, 1])
    return image, mask

# %%
def tf_dataset(images, masks, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((images, masks))
    dataset = dataset.shuffle(buffer_size=5000)
    dataset = dataset.map(preprocess)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(2)
    return dataset

# %%
mirrored_strategy = tf.distribute.MirroredStrategy()
# Out:
# 2023-03-27 16:49:04.419607: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-27 16:49:05.520265: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 78971 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:31:00.0, compute capability: 8.0
# 2023-03-27 16:49:05.521478: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 78971 MB memory:  -> device: 1, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:98:00.0, compute capability: 8.0
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')

# %%
# !unzip segmentation_dataset.zip -d segmentation_train_dataset
# Out:
# /bin/bash: /home/rparchiev/miniconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Archive:  segmentation_dataset.zip
#   inflating: segmentation_train_dataset/people_segmentation/README
#   inflating: segmentation_train_dataset/people_segmentation/images/IMG_3496bfree.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/IMG_3496bfree_pMLnY9FjRH.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/ache-adult-depression-expression-41253.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/active-activity-ball-exercise-41213.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/active-athletic-exercise-female-40974.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/active-cold-female-girl-41371.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/adorable-baby-beautiful-boy-41000.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/adult-attractive-full-body-41215.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/adult-baby-background-bump-41286.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/adult-background-business-computer-53508.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/adult-bag-bags-buy-41277.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/adult-beautiful-beauty-face-41191.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/adult-black-body-costume-41667.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/adult-black-body-costume-41939.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/adult-black-body-costume-41944.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/adult-caucasian-child-daughter-41316.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/adult-cute-face-female-41522.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/advert-advertising-banner-blank-40989.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/advert-advertising-banner-blank-40991.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/africa-namibia-bauer-wagon-68180.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/african-woman-woman-nigeria-woman-black-157968.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/agent-business-call-center-41280.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/air-force-academy-cadet-military-close-up-70576.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/aircraft-women-fashion-pilot-48797.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/alcohol-hangover-event-death-52507.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images/alicia-key-drawing-draw-portrait.jpg
#   inflating: segmentation_train_dataset/people_segmentation/images
png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-69435.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-694438.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-694445.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-694463.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-694629.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-694719.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-694742.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-694745.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-69494.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-695799.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-695893.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-695909.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-695912.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-695914.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-695928.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-695963.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-696011.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-696205.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-696208.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-696955.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-697244.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-697245_PZLPC1oVw5.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-69736.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-69738.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-697509.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-69756.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698165.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698166.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698173.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698487.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698502.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698503.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698538.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698547.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698548.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698552.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698555.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698584.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698848.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698862.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698864.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698865.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698873_OL8vdOAhIV.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698875.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698876.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698878.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698881.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698886.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698889.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698923.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698924.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-698925.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-699813.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-699967.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-700392.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-700446.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-700447.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-700535.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-700579.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-700698_Ot0q9L3fFB.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-700700.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-700701.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-700702.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-700703_uH8OCGIi1J.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-700953.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-701020.png
#   inflating: segmentation_train_dataset/people_segmentation/masks/pexels-photo-701025.png

# %% [markdown]
# ### Train the model

# %%
""" Hyperparameters """
dataset_path = "../input/person-segmentation/people_segmentation"
input_shape = (256, 256, 3)
batch_size = 8
epochs = 10
lr = 1e-4
model_path = "./unet.h5"
csv_path = "./data.csv"

""" Loading the dataset """
(train_x, train_y), (test_x, test_y) = load_data(dataset_path)

train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
valid_dataset = tf_dataset(test_x, test_y, batch=batch_size)

""" Model """
model = build_unet(input_shape)
model.compile(
    loss="binary_crossentropy",
    optimizer=tf.keras.optimizers.Adam(lr),
    metrics=[
        tf.keras.metrics.MeanIoU(num_classes=2),
        tf.keras.metrics.Recall(),
        tf.keras.metrics.Precision()
    ]
)

callbacks = [
    ModelCheckpoint(model_path, monitor="val_loss", verbose=1),
    ReduceLROnPlateau(monitor="val_loss", patience=5, factor=0.1, verbose=1),
    CSVLogger(csv_path),
    EarlyStopping(monitor="val_loss", patience=10)
]

train_steps = len(train_x)//batch_size
if len(train_x) % batch_size != 0:
    train_steps += 1
    
valid_steps = len(test_x)//batch_size
if len(test_x) % batch_size != 0:
    valid_steps += 1

model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs = epochs,
    steps_per_epoch=train_steps,
    validation_steps=valid_steps,
    callbacks=callbacks
)

# %% [markdown]
# ### Test the model

# %%
# https://raw.githubusercontent.com/nikhilroxtomar/Unet-for-Person-Segmentation/main/images/Black-Widow-Avengers.jpg

#test_images = glob("images/*")


test_images = [
    'https://raw.githubusercontent.com/nikhilroxtomar/Unet-for-Person-Segmentation/main/images/Black-Widow-Avengers.jpg'
]

model = tf.keras.models.load_model("./unet.h5")
for path in tqdm(test_images, total=len(test_images)):
    
    req = urllib.request.urlopen(path)
    imgarr = np.asarray(bytearray(req.read()), dtype=np.uint8)
    
    x = cv2.imdecode(imgarr, -1)
    
    #x = cv2.imread(path, cv2.IMREAD_COLOR)
    original_image = x
    h, w, _ = x.shape
    
    x = cv2.resize(x, (256, 256))
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=0)

    pred_mask = model.predict(x)[0]
    pred_mask = cv2.resize(pred_mask, (w, h))
    pred_mask = np.expand_dims(pred_mask, axis=-1)
    pred_mask = pred_mask > 0.5
    
    background_mask = np.abs(1- pred_mask)
        
    masked_image = original_image * pred_mask
    
    background_mask = np.concatenate([background_mask, background_mask, background_mask], axis=-1)
    background_mask = background_mask * [0, 0, 0]
    
    masked_image = masked_image + background_mask
    name = path.split("/")[-1]
    cv2.imwrite(f"{name}.png", masked_image)
